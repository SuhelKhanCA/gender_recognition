# %%
import pandas as pd

# Load the uploaded CSV file
file_path = "/mnt/data/voice.csv"

# Read the first few rows
df = pd.read_csv(file_path)
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Preprocess the dataset
X = df.drop(columns=['label'])  # Features
y = LabelEncoder().fit_transform(df['label'])  # Convert 'male' -> 0, 'female' -> 1

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))

# Save the trained model
model_path = "/mnt/data/gender_model.h5"
model.save(model_path)

# Save the scaler for future use
import joblib
scaler_path = "/mnt/data/scaler.pkl"
joblib.dump(scaler, scaler_path)

model_path, scaler_path
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8354 - loss: 0.4180 - val_accuracy: 0.9795 - val_loss: 0.0731
# Epoch 2/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9703 - loss: 0.0945 - val_accuracy: 0.9811 - val_loss: 0.0607
# Epoch 3/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9718 - loss: 0.0804 - val_accuracy: 0.9858 - val_loss: 0.0592
# Epoch 4/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9699 - loss: 0.0771 - val_accuracy: 0.9811 - val_loss: 0.0547
# Epoch 5/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9774 - loss: 0.0638 - val_accuracy: 0.9795 - val_loss: 0.0586
# Epoch 6/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9802 - loss: 0.0679 - val_accuracy: 0.9826 - val_loss: 0.0527
# Epoch 7/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9802 - loss: 0.0690 - val_accuracy: 0.9779 - val_loss: 0.0540
# Epoch 8/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9775 - loss: 0.0711 - val_accuracy: 0.9795 - val_loss: 0.0518
# Epoch 9/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9778 - loss: 0.0654 - val_accuracy: 0.9811 - val_loss: 0.0527
# Epoch 10/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9783 - loss: 0.0636 - val_accuracy: 0.9795 - val_loss: 0.0550
# Epoch 11/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9749 - loss: 0.0613 - val_accuracy: 0.9811 - val_loss: 0.0535
# Epoch 12/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.0649 - val_accuracy: 0.9795 - val_loss: 0.0524
# Epoch 13/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9838 - loss: 0.0444 - val_accuracy: 0.9811 - val_loss: 0.0531
# Epoch 14/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9831 - loss: 0.0555 - val_accuracy: 0.9811 - val_loss: 0.0518
# Epoch 15/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9844 - loss: 0.0403 - val_accuracy: 0.9811 - val_loss: 0.0534
# Epoch 16/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9857 - loss: 0.0433 - val_accuracy: 0.9826 - val_loss: 0.0545
# Epoch 17/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9853 - loss: 0.0391 - val_accuracy: 0.9811 - val_loss: 0.0555
# Epoch 18/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9810 - loss: 0.0530 - val_accuracy: 0.9795 - val_loss: 0.0520
# Epoch 19/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9806 - loss: 0.0452 - val_accuracy: 0.9795 - val_loss: 0.0523
# Epoch 20/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9817 - loss: 0.0542 - val_accuracy: 0.9811 - val_loss: 0.0496
# Epoch 21/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9870 - loss: 0.0338 - val_accuracy: 0.9763 - val_loss: 0.0536
# Epoch 22/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9855 - loss: 0.0405 - val_accuracy: 0.9811 - val_loss: 0.0490
# Epoch 23/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9788 - loss: 0.0477 - val_accuracy: 0.9811 - val_loss: 0.0486
# Epoch 24/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0356 - val_accuracy: 0.9811 - val_loss: 0.0487
# Epoch 25/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9818 - loss: 0.0404 - val_accuracy: 0.9826 - val_loss: 0.0550
# Epoch 26/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9846 - loss: 0.0371 - val_accuracy: 0.9811 - val_loss: 0.0563
# Epoch 27/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9834 - loss: 0.0429 - val_accuracy: 0.9826 - val_loss: 0.0502
# Epoch 28/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9850 - loss: 0.0385 - val_accuracy: 0.9826 - val_loss: 0.0487
# Epoch 29/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0291 - val_accuracy: 0.9811 - val_loss: 0.0497
# Epoch 30/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9845 - loss: 0.0324 - val_accuracy: 0.9811 - val_loss: 0.0493
# Epoch 31/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9859 - loss: 0.0322 - val_accuracy: 0.9826 - val_loss: 0.0461
# Epoch 32/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9917 - loss: 0.0235 - val_accuracy: 0.9763 - val_loss: 0.0527
# Epoch 33/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0408 - val_accuracy: 0.9811 - val_loss: 0.0492
# Epoch 34/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9878 - loss: 0.0279 - val_accuracy: 0.9811 - val_loss: 0.0500
# Epoch 35/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9823 - loss: 0.0373 - val_accuracy: 0.9795 - val_loss: 0.0531
# Epoch 36/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9863 - loss: 0.0333 - val_accuracy: 0.9795 - val_loss: 0.0512
# Epoch 37/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9919 - loss: 0.0208 - val_accuracy: 0.9795 - val_loss: 0.0460
# Epoch 38/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9906 - loss: 0.0235 - val_accuracy: 0.9795 - val_loss: 0.0558
# Epoch 39/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9894 - loss: 0.0290 - val_accuracy: 0.9826 - val_loss: 0.0544
# Epoch 40/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9872 - loss: 0.0307 - val_accuracy: 0.9811 - val_loss: 0.0509
# Epoch 41/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9885 - loss: 0.0278 - val_accuracy: 0.9826 - val_loss: 0.0514
# Epoch 42/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9926 - loss: 0.0243 - val_accuracy: 0.9779 - val_loss: 0.0512
# Epoch 43/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9898 - loss: 0.0290 - val_accuracy: 0.9811 - val_loss: 0.0525
# Epoch 44/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9801 - loss: 0.0481 - val_accuracy: 0.9842 - val_loss: 0.0508
# Epoch 45/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9896 - loss: 0.0309 - val_accuracy: 0.9795 - val_loss: 0.0588
# Epoch 46/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9840 - loss: 0.0341 - val_accuracy: 0.9826 - val_loss: 0.0559
# Epoch 47/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0296 - val_accuracy: 0.9826 - val_loss: 0.0517
# Epoch 48/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9942 - loss: 0.0177 - val_accuracy: 0.9826 - val_loss: 0.0561
# Epoch 49/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9893 - loss: 0.0235 - val_accuracy: 0.9826 - val_loss: 0.0542
# Epoch 50/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0263 - val_accuracy: 0.9763 - val_loss: 0.0627
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ('/mnt/data/gender_model.h5', '/mnt/data/scaler.pkl')
